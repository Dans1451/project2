# %%
import pandas as pd
import json
import os

# %%
scryfall_df=pd.read_json("Resources/scryfall.json")

# %%
scryfall_df
# Out:
#       object                                    id  \
# 0       card  0000579f-7b35-4ed3-b44c-db2a538066fe
# 1       card  00006596-1166-4a79-8443-ca9f82e6db4e
# 2       card  0000a54c-a511-4925-92dc-01b937f9afad
# 3       card  0000cd57-91fe-411f-b798-646e965eec37
# 4       card  00012bd8-ed68-4978-a22d-f450c8a6e048
# ...      ...                                   ...
# 69499   card  fffaa737-ce46-4f35-aa8c-bd9bb77ed9f6
# 69500   card  fffc0bfd-8e64-44bf-ae0a-5d2ee54c58df
# 69501   card  fffcbc4e-c6dc-4808-b262-f7c453e74dd8
# 69502   card  fffce2f7-b619-4483-a75e-916343194641
# 69503   card  fffe7b2b-22c3-4e6a-9b1b-c6d7b29b9f86
#
#                                   oracle_id multiverse_ids  mtgo_id  \
# 0      44623693-51d6-49ad-8cd7-140505caf02f       [109722]  25527.0
# 1      8ae3562f-28b7-4462-96ed-be0cf7052ccc       [189637]  34586.0
# 2      dc4e2134-f0c2-49aa-9ea3-ebf83af1445c             []      NaN
# 3      9f0d82ae-38bf-45d8-8cda-982b6ead1d72       [435231]  65170.0
# 4      5aa12aff-db3c-4be5-822b-3afdf536b33e         [1278]      NaN
# ...                                     ...            ...      ...
# 69499  de3ed52e-7cc2-49ea-96d9-4254aac46168       [398418]  57710.0
# 69500  dc4a4996-108a-4aac-850f-2d9f76403446             []      NaN
# 69501  2979597d-c3cc-4585-a9b7-7fa15641b030             []      NaN
# 69502  6ecc61ff-719a-405d-b02a-01607729d05c        [45404]  19591.0
# 69503  d7ebd4a7-c542-469f-8a1c-d48b92fa540a       [439664]  66467.0
#
#        mtgo_foil_id  tcgplayer_id  cardmarket_id                 name lang  \
# 0           25528.0       14240.0        13850.0          Fury Sliver   en
# 1           34587.0       33347.0        21851.0        Kor Outfitter   en
# 2               NaN       98659.0            NaN               Spirit   en
# 3           65171.0      145764.0       301766.0        Siren Lookout   en
# 4               NaN        1623.0         5664.0                  Web   en
# ...             ...           ...            ...                  ...  ...
# 69499       57711.0      100411.0       283642.0         Angel's Tomb   en
# 69500           NaN        2054.0         9446.0            Boomerang  zhs
# 69501           NaN       37957.0        21808.0       Celestine Reef   en
# 69502       19592.0       11217.0          893.0         Horned Troll   en
# 69503           NaN      155714.0       315361.0  Exultant Skymarcher   en
#
#        ... card_faces tcgplayer_etched_id color_indicator life_modifier  \
# 0      ...        NaN                 NaN             NaN           NaN
# 1      ...        NaN                 NaN             NaN           NaN
# 2      ...        NaN                 NaN             NaN           NaN
# 3      ...        NaN                 NaN             NaN           NaN
# 4      ...        NaN                 NaN             NaN           NaN
# ...    ...        ...                 ...             ...           ...
# 69499  ...        NaN                 NaN             NaN           NaN
# 69500  ...        NaN                 NaN             NaN           NaN
# 69501  ...        NaN                 NaN             NaN           NaN
# 69502  ...        NaN                 NaN             NaN           NaN
# 69503  ...        NaN                 NaN             NaN           NaN
#
#        hand_modifier printed_type_line printed_text content_warning  \
# 0                NaN               NaN          NaN             NaN
# 1                NaN               NaN          NaN             NaN
# 2                NaN               NaN          NaN             NaN
# 3                NaN               NaN          NaN             NaN
# 4                NaN               NaN          NaN             NaN
# ...              ...               ...          ...             ...
# 69499            NaN               NaN          NaN             NaN
# 69500            NaN               NaN          NaN             NaN
# 69501            NaN               NaN          NaN             NaN
# 69502            NaN               NaN          NaN             NaN
# 69503            NaN               NaN          NaN             NaN
#
#        variation_of flavor_name
# 0               NaN         NaN
# 1               NaN         NaN
# 2               NaN         NaN
# 3               NaN         NaN
# 4               NaN         NaN
# ...             ...         ...
# 69499           NaN         NaN
# 69500           NaN         NaN
# 69501           NaN         NaN
# 69502           NaN         NaN
# 69503           NaN         NaN
#
# [69504 rows x 83 columns]

# %%
mtgjson_df=pd.read_csv("Resources/cards.csv")
# Out:
# C:\Users\prakb\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (10,19,23,26,50,62,70,77) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
scryfall_df.columns
# Out:
# Index(['object', 'id', 'oracle_id', 'multiverse_ids', 'mtgo_id',
#        'mtgo_foil_id', 'tcgplayer_id', 'cardmarket_id', 'name', 'lang',
#        'released_at', 'uri', 'scryfall_uri', 'layout', 'highres_image',
#        'image_status', 'image_uris', 'mana_cost', 'cmc', 'type_line',
#        'oracle_text', 'power', 'toughness', 'colors', 'color_identity',
#        'keywords', 'legalities', 'games', 'reserved', 'foil', 'nonfoil',
#        'finishes', 'oversized', 'promo', 'reprint', 'variation', 'set_id',
#        'set', 'set_name', 'set_type', 'set_uri', 'set_search_uri',
#        'scryfall_set_uri', 'rulings_uri', 'prints_search_uri',
#        'collector_number', 'digital', 'rarity', 'flavor_text', 'card_back_id',
#        'artist', 'artist_ids', 'illustration_id', 'border_color', 'frame',
#        'full_art', 'textless', 'booster', 'story_spotlight', 'edhrec_rank',
#        'penny_rank', 'prices', 'related_uris', 'all_parts', 'promo_types',
#        'arena_id', 'preview', 'security_stamp', 'produced_mana', 'watermark',
#        'frame_effects', 'loyalty', 'printed_name', 'card_faces',
#        'tcgplayer_etched_id', 'color_indicator', 'life_modifier',
#        'hand_modifier', 'printed_type_line', 'printed_text', 'content_warning',
#        'variation_of', 'flavor_name'],
#       dtype='object')

# %%
scryfall_df.id
# Out:
# 0        0000579f-7b35-4ed3-b44c-db2a538066fe
# 1        00006596-1166-4a79-8443-ca9f82e6db4e
# 2        0000a54c-a511-4925-92dc-01b937f9afad
# 3        0000cd57-91fe-411f-b798-646e965eec37
# 4        00012bd8-ed68-4978-a22d-f450c8a6e048
#                          ...
# 69499    fffaa737-ce46-4f35-aa8c-bd9bb77ed9f6
# 69500    fffc0bfd-8e64-44bf-ae0a-5d2ee54c58df
# 69501    fffcbc4e-c6dc-4808-b262-f7c453e74dd8
# 69502    fffce2f7-b619-4483-a75e-916343194641
# 69503    fffe7b2b-22c3-4e6a-9b1b-c6d7b29b9f86
# Name: id, Length: 69504, dtype: object

# %%
scryfall_df.loc[scryfall_df['set']=='5ed']
# Out:
#       object                                    id  \
# 74      card  00427d72-b140-45eb-b2ec-2ac2dab16966
# 85      card  004b6463-0aef-4419-b4f2-dc3fa6eee901
# 195     card  00a4ffc1-7731-42d9-b970-2a8d84cba14d
# 299     card  010d1107-a18c-4e25-86c7-8e09cba72a12
# 314     card  011b1e44-776a-44b9-a976-777e49ae628e
# ...      ...                                   ...
# 69306   card  ff4d1549-d0d5-48f8-9d8a-2e2940523307
# 69349   card  ff6aee0b-1039-496f-a096-2d4d71621d99
# 69364   card  ff73c4c8-1761-4fc8-96b1-8983b9b78b46
# 69490   card  ffef6ac8-a42c-4025-b4ef-3f772129b8f7
# 69500   card  fffc0bfd-8e64-44bf-ae0a-5d2ee54c58df
#
#                                   oracle_id multiverse_ids  mtgo_id  \
# 74     a3a98bc9-caa0-49b7-951c-fe4e4f54e4ba         [3805]      NaN
# 85     a60422e8-f2f4-4c37-a0f4-eedad27eb08c         [3934]      NaN
# 195    78826359-fe63-44ad-adc4-a17ffcd710e4         [3999]      NaN
# 299    1973f1e9-aa14-49dc-bafe-be17b30ba288         [3776]      NaN
# 314    d89075a3-4413-4796-a055-eef51fddb7f3         [3950]      NaN
# ...                                     ...            ...      ...
# 69306  74f361f8-a0d8-4824-9380-61469d6a19cf         [4006]      NaN
# 69349  ced4538a-4919-4ef8-8bf2-2de9e0388587         [3856]      NaN
# 69364  1c68e877-ee47-42bf-a867-3f7f479eae1c         [3858]      NaN
# 69490  0f1afedd-c60f-454f-b84a-c8117aec0128             []      NaN
# 69500  dc4a4996-108a-4aac-850f-2d9f76403446             []      NaN
#
#        mtgo_foil_id  tcgplayer_id  cardmarket_id            name lang  ...  \
# 74              NaN        2304.0         9765.0     Ornithopter   en  ...
# 85              NaN        2331.0         9484.0   Psychic Venom   en  ...
# 195             NaN        2288.0         9549.0   Nature's Lore   en  ...
# 299             NaN        2108.0         9735.0      Dingus Egg   en  ...
# 314             NaN        2408.0         9500.0  Time Elemental   en  ...
# ...             ...           ...            ...             ...  ...  ...
# 69306           NaN        2354.0         9556.0  Scavenger Folk   en  ...
# 69349           NaN        2249.0         9406.0  Leshrac's Rite   en  ...
# 69364           NaN        2261.0         9408.0       Lost Soul   en  ...
# 69490           NaN        2268.0         9622.0       Manabarbs   en  ...
# 69500           NaN        2054.0         9446.0       Boomerang  zhs  ...
#
#       card_faces tcgplayer_etched_id color_indicator life_modifier  \
# 74           NaN                 NaN             NaN           NaN
# 85           NaN                 NaN             NaN           NaN
# 195          NaN                 NaN             NaN           NaN
# 299          NaN                 NaN             NaN           NaN
# 314          NaN                 NaN             NaN           NaN
# ...          ...                 ...             ...           ...
# 69306        NaN                 NaN             NaN           NaN
# 69349        NaN                 NaN             NaN           NaN
# 69364        NaN                 NaN             NaN           NaN
# 69490        NaN                 NaN             NaN           NaN
# 69500        NaN                 NaN             NaN           NaN
#
#        hand_modifier printed_type_line printed_text content_warning  \
# 74               NaN               NaN          NaN             NaN
# 85               NaN               NaN          NaN             NaN
# 195              NaN               NaN          NaN             NaN
# 299              NaN               NaN          NaN             NaN
# 314              NaN               NaN          NaN             NaN
# ...              ...               ...          ...             ...
# 69306            NaN               NaN          NaN             NaN
# 69349            NaN               NaN          NaN             NaN
# 69364            NaN               NaN          NaN             NaN
# 69490            NaN               NaN          NaN             NaN
# 69500            NaN               NaN          NaN             NaN
#
#                                variation_of flavor_name
# 74                                      NaN         NaN
# 85                                      NaN         NaN
# 195                                     NaN         NaN
# 299                                     NaN         NaN
# 314                                     NaN         NaN
# ...                                     ...         ...
# 69306                                   NaN         NaN
# 69349                                   NaN         NaN
# 69364                                   NaN         NaN
# 69490  f55a2d1d-0964-44a9-9f32-09804f2c7445         NaN
# 69500                                   NaN         NaN
#
# [460 rows x 83 columns]

# %%
scryfall_df.rulings_uri
# Out:
# 0        https://api.scryfall.com/cards/0000579f-7b35-4...
# 1        https://api.scryfall.com/cards/00006596-1166-4...
# 2        https://api.scryfall.com/cards/0000a54c-a511-4...
# 3        https://api.scryfall.com/cards/0000cd57-91fe-4...
# 4        https://api.scryfall.com/cards/00012bd8-ed68-4...
#                                ...
# 69499    https://api.scryfall.com/cards/fffaa737-ce46-4...
# 69500    https://api.scryfall.com/cards/fffc0bfd-8e64-4...
# 69501    https://api.scryfall.com/cards/fffcbc4e-c6dc-4...
# 69502    https://api.scryfall.com/cards/fffce2f7-b619-4...
# 69503    https://api.scryfall.com/cards/fffe7b2b-22c3-4...
# Name: rulings_uri, Length: 69504, dtype: object

# %%
mtgjson_df
# Out:
#        index     id         artist asciiName availability boosterTypes  \
# 0          0      1  Adam Paquette       NaN        paper          NaN
# 1          1      2  Adam Paquette       NaN        paper          NaN
# 2          2      3  Adam Paquette       NaN        paper          NaN
# 3          3      4  Adam Paquette       NaN        paper          NaN
# 4          4      5  Adam Paquette       NaN        paper          NaN
# ...      ...    ...            ...       ...          ...          ...
# 67913  67913  67914  Jesper Ejsing       NaN        paper          NaN
# 67914  67914  67915    Howard Lyon       NaN        paper          NaN
# 67915  67915  67916   Chuck Lukacs       NaN        paper          NaN
# 67916  67916  67917    Val Mayerik       NaN        paper          NaN
# 67917  67917  67918    Jim Pavelec       NaN        paper          NaN
#
#       borderColor  cardKingdomEtchedId  cardKingdomFoilId  cardKingdomId  ...  \
# 0           black                  NaN           216615.0       216601.0  ...
# 1           black                  NaN           216614.0       216602.0  ...
# 2           black                  NaN           216613.0       216603.0  ...
# 3           black                  NaN           216612.0       216604.0  ...
# 4           black                  NaN           216611.0       216605.0  ...
# ...           ...                  ...                ...            ...  ...
# 67913       black                  NaN                NaN            NaN  ...
# 67914       black                  NaN                NaN            NaN  ...
# 67915       black                  NaN                NaN            NaN  ...
# 67916       black                  NaN                NaN            NaN  ...
# 67917       black                  NaN                NaN            NaN  ...
#
#       supertypes  tcgplayerEtchedProductId tcgplayerProductId  \
# 0          Basic                       NaN            80285.0
# 1          Basic                       NaN           101548.0
# 2          Basic                       NaN            80286.0
# 3          Basic                       NaN            80287.0
# 4          Basic                       NaN            80288.0
# ...          ...                       ...                ...
# 67913        NaN                       NaN            77318.0
# 67914        NaN                       NaN            70905.0
# 67915    Ongoing                       NaN            70906.0
# 67916        NaN                       NaN            70907.0
# 67917    Ongoing                       NaN            70908.0
#
#                                                     text toughness  \
# 0                                        ({T}: Add {W}.)       NaN
# 1                                        ({T}: Add {U}.)       NaN
# 2                                        ({T}: Add {B}.)       NaN
# 3                                        ({T}: Add {R}.)       NaN
# 4                                        ({T}: Add {G}.)       NaN
# ...                                                  ...       ...
# 67913  When you set this scheme in motion, the next t...       NaN
# 67914  When you set this scheme in motion, search you...       NaN
# 67915  (An ongoing scheme remains face up.)\nAt the b...       NaN
# 67916  When you set this scheme in motion, after this...       NaN
# 67917  (An ongoing scheme remains face up until it's ...       NaN
#
#                         type   types                                  uuid  \
# 0        Basic Land — Plains    Land  53532290-9194-5066-9318-b9cc09c52d8f
# 1        Basic Land — Island    Land  4afd42fa-3e78-5e83-8320-dd5d13147038
# 2         Basic Land — Swamp    Land  3296e05b-7dae-5298-97a1-f33f3564ab88
# 3      Basic Land — Mountain    Land  83f5d717-4492-5ed7-9211-036b604524ad
# 4        Basic Land — Forest    Land  ab25e0c6-a0a0-56f7-9b17-efb5797d389a
# ...                      ...     ...                                   ...
# 67913                 Scheme  Scheme  343f2c52-2a6d-59b8-b71a-91819232428b
# 67914                 Scheme  Scheme  c24b6976-dcae-5d93-b6fa-0c46c7bdaae9
# 67915         Ongoing Scheme  Scheme  c7d8e097-8654-5f92-b1d7-1ce8fcca99dd
# 67916                 Scheme  Scheme  a2006e32-0dde-533d-8da2-654d88b44d22
# 67917         Ongoing Scheme  Scheme  2b31e191-b203-500b-9433-fd47cefc02fa
#
#        variations watermark
# 0             NaN       NaN
# 1             NaN       NaN
# 2             NaN       NaN
# 3             NaN       NaN
# 4             NaN       NaN
# ...           ...       ...
# 67913         NaN       NaN
# 67914         NaN       NaN
# 67915         NaN       NaN
# 67916         NaN       NaN
# 67917         NaN       NaN
#
# [67918 rows x 89 columns]

# %%
mtgjson_df.columns
# Out:
# Index(['index', 'id', 'artist', 'asciiName', 'availability', 'boosterTypes',
#        'borderColor', 'cardKingdomEtchedId', 'cardKingdomFoilId',
#        'cardKingdomId', 'cardParts', 'cardsphereId', 'colorIdentity',
#        'colorIndicator', 'colors', 'convertedManaCost', 'duelDeck',
#        'edhrecRank', 'faceConvertedManaCost', 'faceFlavorName',
#        'faceManaValue', 'faceName', 'finishes', 'flavorName', 'flavorText',
#        'frameEffects', 'frameVersion', 'hand', 'hasAlternativeDeckLimit',
#        'hasContentWarning', 'hasFoil', 'hasNonFoil', 'isAlternative',
#        'isFullArt', 'isFunny', 'isOnlineOnly', 'isOversized', 'isPromo',
#        'isRebalanced', 'isReprint', 'isReserved', 'isStarter',
#        'isStorySpotlight', 'isTextless', 'isTimeshifted', 'keywords',
#        'language', 'layout', 'leadershipSkills', 'life', 'loyalty', 'manaCost',
#        'manaValue', 'mcmId', 'mcmMetaId', 'mtgArenaId', 'mtgjsonV4Id',
#        'mtgoFoilId', 'mtgoId', 'multiverseId', 'name', 'number',
#        'originalPrintings', 'originalReleaseDate', 'otherFaceIds', 'power',
#        'printings', 'promoTypes', 'purchaseUrls', 'rarity',
#        'rebalancedPrintings', 'scryfallId', 'scryfallIllustrationId',
#        'scryfallOracleId', 'securityStamp', 'setCode', 'side', 'signature',
#        'subtypes', 'supertypes', 'tcgplayerEtchedProductId',
#        'tcgplayerProductId', 'text', 'toughness', 'type', 'types', 'uuid',
#        'variations', 'watermark'],
#       dtype='object')

# %%
mtgjson_dropped_df=mtgjson_df[[ 'name','availability', 'boosterTypes','mtgjsonV4Id','purchaseUrls', 'scryfallId',  'setCode',  'uuid']]

# %%
mtgjson_dropped_df
# Out:
#                                  name availability boosterTypes  \
# 0                              Plains        paper          NaN
# 1                              Island        paper          NaN
# 2                               Swamp        paper          NaN
# 3                            Mountain        paper          NaN
# 4                              Forest        paper          NaN
# ...                               ...          ...          ...
# 67913       Plots That Span Centuries        paper          NaN
# 67914    Perhaps You've Met My Cohort        paper          NaN
# 67915           Your Inescapable Doom        paper          NaN
# 67916  Drench the Soil in Their Blood        paper          NaN
# 67917   Imprison This Insolent Wretch        paper          NaN
#
#                                 mtgjsonV4Id  \
# 0      bce00f49-d365-5ba2-ba04-0ec1fb075282
# 1      e15d79ed-dd51-5005-ace0-4e3f908310ab
# 2      dda558c2-9c6e-5ac6-870f-b1d40abd4cdc
# 3      ba172288-733b-590a-8836-79cd03c18bc8
# 4      4f53a137-3450-5991-8866-9de8d26635f4
# ...                                     ...
# 67913  fe3ef3e2-2d22-5c2b-a6aa-23064d50eed6
# 67914  8491be80-300f-5385-bf20-adf6d8e2b806
# 67915  1d99229a-e9fc-501b-b75b-e76a48cc604c
# 67916  b731fbe5-54ea-5648-a9ab-405adaf20226
# 67917  aac57d45-2a25-56da-ab3b-10ab7e1f2a2a
#
#                                             purchaseUrls  \
# 0      {'tcgplayer': 'https://mtgjson.com/links/9ffe8...
# 1      {'tcgplayer': 'https://mtgjson.com/links/77fdc...
# 2      {'tcgplayer': 'https://mtgjson.com/links/8f4db...
# 3      {'tcgplayer': 'https://mtgjson.com/links/b6c8a...
# 4      {'tcgplayer': 'https://mtgjson.com/links/01352...
# ...                                                  ...
# 67913  {'tcgplayer': 'https://mtgjson.com/links/073b5...
# 67914  {'tcgplayer': 'https://mtgjson.com/links/87921...
# 67915  {'tcgplayer': 'https://mtgjson.com/links/32de0...
# 67916  {'tcgplayer': 'https://mtgjson.com/links/d796f...
# 67917  {'tcgplayer': 'https://mtgjson.com/links/457aa...
#
#                                  scryfallId setCode  \
# 0      7ee52536-8cfa-482b-874e-094c0a081894  PMPS11
# 1      161aaceb-d0bb-48c5-8bd4-bff321a94b2e  PMPS11
# 2      4df49e68-cadf-4196-a3f4-ae38579edaeb  PMPS11
# 3      890037ae-c366-4769-b7f7-7185a1bebca1  PMPS11
# 4      86dae285-a59c-426c-b6cd-3683abea75a3  PMPS11
# ...                                     ...     ...
# 67913  438cab33-ffb1-4fba-8c2a-2c91fd39b9a2    PARC
# 67914  9fdda372-05b0-47ca-ac74-713037bcac17    PARC
# 67915  9badcc58-0281-499c-9e1f-5d894761ca61    PARC
# 67916  14e5d253-e075-4df4-98af-4ae43c000634    PARC
# 67917  fee17785-2a29-4998-a34e-b738de955d53    PARC
#
#                                        uuid
# 0      53532290-9194-5066-9318-b9cc09c52d8f
# 1      4afd42fa-3e78-5e83-8320-dd5d13147038
# 2      3296e05b-7dae-5298-97a1-f33f3564ab88
# 3      83f5d717-4492-5ed7-9211-036b604524ad
# 4      ab25e0c6-a0a0-56f7-9b17-efb5797d389a
# ...                                     ...
# 67913  343f2c52-2a6d-59b8-b71a-91819232428b
# 67914  c24b6976-dcae-5d93-b6fa-0c46c7bdaae9
# 67915  c7d8e097-8654-5f92-b1d7-1ce8fcca99dd
# 67916  a2006e32-0dde-533d-8da2-654d88b44d22
# 67917  2b31e191-b203-500b-9433-fd47cefc02fa
#
# [67918 rows x 8 columns]

# %%
print(mtgjson_df.purchaseUrls)
# Out:
# 0        {'tcgplayer': 'https://mtgjson.com/links/9ffe8...
# 1        {'tcgplayer': 'https://mtgjson.com/links/77fdc...
# 2        {'tcgplayer': 'https://mtgjson.com/links/8f4db...
# 3        {'tcgplayer': 'https://mtgjson.com/links/b6c8a...
# 4        {'tcgplayer': 'https://mtgjson.com/links/01352...
#                                ...
# 67913    {'tcgplayer': 'https://mtgjson.com/links/073b5...
# 67914    {'tcgplayer': 'https://mtgjson.com/links/87921...
# 67915    {'tcgplayer': 'https://mtgjson.com/links/32de0...
# 67916    {'tcgplayer': 'https://mtgjson.com/links/d796f...
# 67917    {'tcgplayer': 'https://mtgjson.com/links/457aa...
# Name: purchaseUrls, Length: 67918, dtype: object

# %%
mtgjson_df.printings.str.split(',')
# Out:
# 0        [10E, 2ED, 2XM, 3ED, 4BB, 4ED, 5ED, 6ED, 7ED, ...
# 1        [10E, 2ED, 2XM, 3ED, 4BB, 4ED, 5ED, 6ED, 7ED, ...
# 2        [10E, 2ED, 2XM, 3ED, 4BB, 4ED, 5ED, 6ED, 7ED, ...
# 3        [10E, 2ED, 2XM, 3ED, 4BB, 4ED, 5ED, 6ED, 7ED, ...
# 4        [10E, 2ED, 2XM, 3ED, 4BB, 4ED, 5ED, 6ED, 7ED, ...
#                                ...
# 67913                                               [PARC]
# 67914                                               [PARC]
# 67915                                               [PARC]
# 67916                                               [PARC]
# 67917                                               [PARC]
# Name: printings, Length: 67918, dtype: object

# %%
mtgjson_df.explode('printings')
# Out:
#        index     id         artist asciiName availability boosterTypes  \
# 0          0      1  Adam Paquette       NaN        paper          NaN
# 1          1      2  Adam Paquette       NaN        paper          NaN
# 2          2      3  Adam Paquette       NaN        paper          NaN
# 3          3      4  Adam Paquette       NaN        paper          NaN
# 4          4      5  Adam Paquette       NaN        paper          NaN
# ...      ...    ...            ...       ...          ...          ...
# 67913  67913  67914  Jesper Ejsing       NaN        paper          NaN
# 67914  67914  67915    Howard Lyon       NaN        paper          NaN
# 67915  67915  67916   Chuck Lukacs       NaN        paper          NaN
# 67916  67916  67917    Val Mayerik       NaN        paper          NaN
# 67917  67917  67918    Jim Pavelec       NaN        paper          NaN
#
#       borderColor  cardKingdomEtchedId  cardKingdomFoilId  cardKingdomId  ...  \
# 0           black                  NaN           216615.0       216601.0  ...
# 1           black                  NaN           216614.0       216602.0  ...
# 2           black                  NaN           216613.0       216603.0  ...
# 3           black                  NaN           216612.0       216604.0  ...
# 4           black                  NaN           216611.0       216605.0  ...
# ...           ...                  ...                ...            ...  ...
# 67913       black                  NaN                NaN            NaN  ...
# 67914       black                  NaN                NaN            NaN  ...
# 67915       black                  NaN                NaN            NaN  ...
# 67916       black                  NaN                NaN            NaN  ...
# 67917       black                  NaN                NaN            NaN  ...
#
#       supertypes  tcgplayerEtchedProductId tcgplayerProductId  \
# 0          Basic                       NaN            80285.0
# 1          Basic                       NaN           101548.0
# 2          Basic                       NaN            80286.0
# 3          Basic                       NaN            80287.0
# 4          Basic                       NaN            80288.0
# ...          ...                       ...                ...
# 67913        NaN                       NaN            77318.0
# 67914        NaN                       NaN            70905.0
# 67915    Ongoing                       NaN            70906.0
# 67916        NaN                       NaN            70907.0
# 67917    Ongoing                       NaN            70908.0
#
#                                                     text toughness  \
# 0                                        ({T}: Add {W}.)       NaN
# 1                                        ({T}: Add {U}.)       NaN
# 2                                        ({T}: Add {B}.)       NaN
# 3                                        ({T}: Add {R}.)       NaN
# 4                                        ({T}: Add {G}.)       NaN
# ...                                                  ...       ...
# 67913  When you set this scheme in motion, the next t...       NaN
# 67914  When you set this scheme in motion, search you...       NaN
# 67915  (An ongoing scheme remains face up.)\nAt the b...       NaN
# 67916  When you set this scheme in motion, after this...       NaN
# 67917  (An ongoing scheme remains face up until it's ...       NaN
#
#                         type   types                                  uuid  \
# 0        Basic Land — Plains    Land  53532290-9194-5066-9318-b9cc09c52d8f
# 1        Basic Land — Island    Land  4afd42fa-3e78-5e83-8320-dd5d13147038
# 2         Basic Land — Swamp    Land  3296e05b-7dae-5298-97a1-f33f3564ab88
# 3      Basic Land — Mountain    Land  83f5d717-4492-5ed7-9211-036b604524ad
# 4        Basic Land — Forest    Land  ab25e0c6-a0a0-56f7-9b17-efb5797d389a
# ...                      ...     ...                                   ...
# 67913                 Scheme  Scheme  343f2c52-2a6d-59b8-b71a-91819232428b
# 67914                 Scheme  Scheme  c24b6976-dcae-5d93-b6fa-0c46c7bdaae9
# 67915         Ongoing Scheme  Scheme  c7d8e097-8654-5f92-b1d7-1ce8fcca99dd
# 67916                 Scheme  Scheme  a2006e32-0dde-533d-8da2-654d88b44d22
# 67917         Ongoing Scheme  Scheme  2b31e191-b203-500b-9433-fd47cefc02fa
#
#        variations watermark
# 0             NaN       NaN
# 1             NaN       NaN
# 2             NaN       NaN
# 3             NaN       NaN
# 4             NaN       NaN
# ...           ...       ...
# 67913         NaN       NaN
# 67914         NaN       NaN
# 67915         NaN       NaN
# 67916         NaN       NaN
# 67917         NaN       NaN
#
# [67918 rows x 89 columns]

# %%
mtgjson_df.loc[mtgjson_df['name']=='Plains']
# Out:
#        index     id         artist asciiName      availability boosterTypes  \
# 0          0      1  Adam Paquette       NaN             paper          NaN
# 234      234    235      John Avon       NaN        mtgo,paper        draft
# 235      235    236    Jonas De Ro       NaN        mtgo,paper        draft
# 236      236    237      Nils Hamm       NaN        mtgo,paper        draft
# 237      237    238  Andreas Rocha       NaN        mtgo,paper        draft
# ...      ...    ...            ...       ...               ...          ...
# 66862  66862  66863  Andreas Rocha       NaN  arena,mtgo,paper        draft
# 66909  66909  66910    Jonas De Ro       NaN  arena,mtgo,paper          NaN
# 67238  67238  67239     Sam Burley       NaN             paper          NaN
# 67239  67239  67240  Adam Paquette       NaN             paper          NaN
# 67248  67248  67249     Mark Poole       NaN             paper          NaN
#
#       borderColor  cardKingdomEtchedId  cardKingdomFoilId  cardKingdomId  ...  \
# 0           black                  NaN           216615.0       216601.0  ...
# 234         black                  NaN           191037.0       192160.0  ...
# 235         black                  NaN           200641.0       192161.0  ...
# 236         black                  NaN           200642.0       192162.0  ...
# 237         black                  NaN           200643.0       192163.0  ...
# ...           ...                  ...                ...            ...  ...
# 66862       black                  NaN           234502.0       234195.0  ...
# 66909       black                  NaN           234617.0       233991.0  ...
# 67238       black                  NaN                NaN       231752.0  ...
# 67239       black                  NaN           231832.0       231753.0  ...
# 67248       black                  NaN           216128.0            NaN  ...
#
#       supertypes  tcgplayerEtchedProductId tcgplayerProductId  \
# 0          Basic                       NaN            80285.0
# 234        Basic                       NaN            69902.0
# 235        Basic                       NaN            69903.0
# 236        Basic                       NaN            69904.0
# 237        Basic                       NaN            69905.0
# ...          ...                       ...                ...
# 66862      Basic                       NaN           215715.0
# 66909      Basic                       NaN           215509.0
# 67238      Basic                       NaN           208392.0
# 67239      Basic                       NaN           208386.0
# 67248      Basic                       NaN           148752.0
#
#                   text toughness                 type types  \
# 0      ({T}: Add {W}.)       NaN  Basic Land — Plains  Land
# 234    ({T}: Add {W}.)       NaN  Basic Land — Plains  Land
# 235    ({T}: Add {W}.)       NaN  Basic Land — Plains  Land
# 236    ({T}: Add {W}.)       NaN  Basic Land — Plains  Land
# 237    ({T}: Add {W}.)       NaN  Basic Land — Plains  Land
# ...                ...       ...                  ...   ...
# 66862  ({T}: Add {W}.)       NaN  Basic Land — Plains  Land
# 66909  ({T}: Add {W}.)       NaN  Basic Land — Plains  Land
# 67238  ({T}: Add {W}.)       NaN  Basic Land — Plains  Land
# 67239  ({T}: Add {W}.)       NaN  Basic Land — Plains  Land
# 67248  ({T}: Add {W}.)       NaN  Basic Land — Plains  Land
#
#                                        uuid  \
# 0      53532290-9194-5066-9318-b9cc09c52d8f
# 234    80883bcc-dd8f-5ba9-a87f-463db64f5d9b
# 235    235fd614-de6d-5dc2-a1d7-2d9d19d73b2f
# 236    8e987378-0c30-54ed-8d85-4d7df1aeb275
# 237    b6bdcad0-63ed-5e7a-9a36-3e25807e8a5a
# ...                                     ...
# 66862  364598a6-6bce-53b0-9755-4e726858f269
# 66909  d6c798e1-56b7-5edf-9253-d2fdf7c6c79f
# 67238  df3a4387-62c5-5fcc-a675-1c5e04d6103b
# 67239  19c6f196-f59b-5e2c-b412-a03c4795427e
# 67248  98addd47-09a7-54b4-98ea-04a8be03ac06
#
#                                               variations watermark
# 0                                                    NaN       NaN
# 234    235fd614-de6d-5dc2-a1d7-2d9d19d73b2f,8e987378-...       NaN
# 235    80883bcc-dd8f-5ba9-a87f-463db64f5d9b,8e987378-...       NaN
# 236    80883bcc-dd8f-5ba9-a87f-463db64f5d9b,235fd614-...       NaN
# 237    80883bcc-dd8f-5ba9-a87f-463db64f5d9b,235fd614-...       NaN
# ...                                                  ...       ...
# 66862  983bac6e-2e3d-5459-8798-480e84d3b6af,daf4f9c6-...       NaN
# 66909  983bac6e-2e3d-5459-8798-480e84d3b6af,daf4f9c6-...       NaN
# 67238               19c6f196-f59b-5e2c-b412-a03c4795427e       NaN
# 67239               df3a4387-62c5-5fcc-a675-1c5e04d6103b       NaN
# 67248                                                NaN       NaN
#
# [676 rows x 89 columns]

# %%
rulings_df=pd.read_csv("Resources/rulings.csv")

# %%
rulings_df.head()
# Out:
#    index  id        date                                               text  \
# 0      0   1  2012-07-01  The number of Cat tokens you put onto the batt...
# 1      1   2  2012-07-01  You can activate the first ability without a t...
# 2      2   3  2013-07-01  The ability doesn’t trigger until the enchantm...
# 3      3   4  2013-07-01  If you cast an Aura targeting an opponent or a...
# 4      4   5  2013-07-01  You may attach the Aura to the token only if i...
#
#                                    uuid
# 0  79b0e970-207d-56b9-8fe3-aeb2c486444a
# 1  79b0e970-207d-56b9-8fe3-aeb2c486444a
# 2  8363e365-c16e-5f64-9d23-412bd6d54488
# 3  8363e365-c16e-5f64-9d23-412bd6d54488
# 4  8363e365-c16e-5f64-9d23-412bd6d54488

# %%
scryfall_dropped_df=scryfall_df[['object', 'id', 'oracle_id',  'mtgo_id',
       'mtgo_foil_id', 'tcgplayer_id', 'cardmarket_id', 'name', 'lang',
       'released_at',  'layout', 'mana_cost', 'cmc', 'type_line',
       'oracle_text', 'power', 'toughness', 'colors', 'color_identity',
       'keywords', 'legalities', 'games', 'reserved', 'foil', 'nonfoil',
       'finishes', 'oversized', 'promo', 'reprint', 'variation', 'set_id',
       'set', 'set_name', 'set_type', 'collector_number', 'digital', 'rarity', 'flavor_text', 'card_back_id',
       'artist', 'artist_ids', 'illustration_id', 'border_color', 'frame',
       'full_art', 'textless', 'booster', 'story_spotlight', 'edhrec_rank',
       'penny_rank','promo_types',
       'arena_id', 'security_stamp', 'produced_mana', 'watermark',
       'frame_effects', 'loyalty',  'card_faces',
       'tcgplayer_etched_id', 'color_indicator', 'life_modifier',
       'hand_modifier', 'variation_of', 'flavor_name']]

# %%
scryfall_dropped_df
# Out:
#       object                                    id  \
# 0       card  0000579f-7b35-4ed3-b44c-db2a538066fe
# 1       card  00006596-1166-4a79-8443-ca9f82e6db4e
# 2       card  0000a54c-a511-4925-92dc-01b937f9afad
# 3       card  0000cd57-91fe-411f-b798-646e965eec37
# 4       card  00012bd8-ed68-4978-a22d-f450c8a6e048
# ...      ...                                   ...
# 69499   card  fffaa737-ce46-4f35-aa8c-bd9bb77ed9f6
# 69500   card  fffc0bfd-8e64-44bf-ae0a-5d2ee54c58df
# 69501   card  fffcbc4e-c6dc-4808-b262-f7c453e74dd8
# 69502   card  fffce2f7-b619-4483-a75e-916343194641
# 69503   card  fffe7b2b-22c3-4e6a-9b1b-c6d7b29b9f86
#
#                                   oracle_id  mtgo_id  mtgo_foil_id  \
# 0      44623693-51d6-49ad-8cd7-140505caf02f  25527.0       25528.0
# 1      8ae3562f-28b7-4462-96ed-be0cf7052ccc  34586.0       34587.0
# 2      dc4e2134-f0c2-49aa-9ea3-ebf83af1445c      NaN           NaN
# 3      9f0d82ae-38bf-45d8-8cda-982b6ead1d72  65170.0       65171.0
# 4      5aa12aff-db3c-4be5-822b-3afdf536b33e      NaN           NaN
# ...                                     ...      ...           ...
# 69499  de3ed52e-7cc2-49ea-96d9-4254aac46168  57710.0       57711.0
# 69500  dc4a4996-108a-4aac-850f-2d9f76403446      NaN           NaN
# 69501  2979597d-c3cc-4585-a9b7-7fa15641b030      NaN           NaN
# 69502  6ecc61ff-719a-405d-b02a-01607729d05c  19591.0       19592.0
# 69503  d7ebd4a7-c542-469f-8a1c-d48b92fa540a  66467.0           NaN
#
#        tcgplayer_id  cardmarket_id                 name lang released_at  ...  \
# 0           14240.0        13850.0          Fury Sliver   en  2006-10-06  ...
# 1           33347.0        21851.0        Kor Outfitter   en  2009-10-02  ...
# 2           98659.0            NaN               Spirit   en  2015-05-22  ...
# 3          145764.0       301766.0        Siren Lookout   en  2017-09-29  ...
# 4            1623.0         5664.0                  Web   en  1994-04-01  ...
# ...             ...            ...                  ...  ...         ...  ...
# 69499      100411.0       283642.0         Angel's Tomb   en  2015-07-17  ...
# 69500        2054.0         9446.0            Boomerang  zhs  1997-03-24  ...
# 69501       37957.0        21808.0       Celestine Reef   en  2009-09-04  ...
# 69502       11217.0          893.0         Horned Troll   en  2003-07-28  ...
# 69503      155714.0       315361.0  Exultant Skymarcher   en  2018-01-19  ...
#
#       watermark frame_effects  loyalty card_faces tcgplayer_etched_id  \
# 0           NaN           NaN      NaN        NaN                 NaN
# 1           NaN           NaN      NaN        NaN                 NaN
# 2           NaN           NaN      NaN        NaN                 NaN
# 3           NaN           NaN      NaN        NaN                 NaN
# 4           NaN           NaN      NaN        NaN                 NaN
# ...         ...           ...      ...        ...                 ...
# 69499       NaN           NaN      NaN        NaN                 NaN
# 69500       NaN           NaN      NaN        NaN                 NaN
# 69501       NaN           NaN      NaN        NaN                 NaN
# 69502       NaN           NaN      NaN        NaN                 NaN
# 69503       NaN           NaN      NaN        NaN                 NaN
#
#       color_indicator life_modifier hand_modifier variation_of flavor_name
# 0                 NaN           NaN           NaN          NaN         NaN
# 1                 NaN           NaN           NaN          NaN         NaN
# 2                 NaN           NaN           NaN          NaN         NaN
# 3                 NaN           NaN           NaN          NaN         NaN
# 4                 NaN           NaN           NaN          NaN         NaN
# ...               ...           ...           ...          ...         ...
# 69499             NaN           NaN           NaN          NaN         NaN
# 69500             NaN           NaN           NaN          NaN         NaN
# 69501             NaN           NaN           NaN          NaN         NaN
# 69502             NaN           NaN           NaN          NaN         NaN
# 69503             NaN           NaN           NaN          NaN         NaN
#
# [69504 rows x 64 columns]

# %%
scryfall_dropped_df.rename(columns={'id':'scryfallId'})
# Out:
#       object                            scryfallId  \
# 0       card  0000579f-7b35-4ed3-b44c-db2a538066fe
# 1       card  00006596-1166-4a79-8443-ca9f82e6db4e
# 2       card  0000a54c-a511-4925-92dc-01b937f9afad
# 3       card  0000cd57-91fe-411f-b798-646e965eec37
# 4       card  00012bd8-ed68-4978-a22d-f450c8a6e048
# ...      ...                                   ...
# 69499   card  fffaa737-ce46-4f35-aa8c-bd9bb77ed9f6
# 69500   card  fffc0bfd-8e64-44bf-ae0a-5d2ee54c58df
# 69501   card  fffcbc4e-c6dc-4808-b262-f7c453e74dd8
# 69502   card  fffce2f7-b619-4483-a75e-916343194641
# 69503   card  fffe7b2b-22c3-4e6a-9b1b-c6d7b29b9f86
#
#                                   oracle_id  mtgo_id  mtgo_foil_id  \
# 0      44623693-51d6-49ad-8cd7-140505caf02f  25527.0       25528.0
# 1      8ae3562f-28b7-4462-96ed-be0cf7052ccc  34586.0       34587.0
# 2      dc4e2134-f0c2-49aa-9ea3-ebf83af1445c      NaN           NaN
# 3      9f0d82ae-38bf-45d8-8cda-982b6ead1d72  65170.0       65171.0
# 4      5aa12aff-db3c-4be5-822b-3afdf536b33e      NaN           NaN
# ...                                     ...      ...           ...
# 69499  de3ed52e-7cc2-49ea-96d9-4254aac46168  57710.0       57711.0
# 69500  dc4a4996-108a-4aac-850f-2d9f76403446      NaN           NaN
# 69501  2979597d-c3cc-4585-a9b7-7fa15641b030      NaN           NaN
# 69502  6ecc61ff-719a-405d-b02a-01607729d05c  19591.0       19592.0
# 69503  d7ebd4a7-c542-469f-8a1c-d48b92fa540a  66467.0           NaN
#
#        tcgplayer_id  cardmarket_id                 name lang released_at  ...  \
# 0           14240.0        13850.0          Fury Sliver   en  2006-10-06  ...
# 1           33347.0        21851.0        Kor Outfitter   en  2009-10-02  ...
# 2           98659.0            NaN               Spirit   en  2015-05-22  ...
# 3          145764.0       301766.0        Siren Lookout   en  2017-09-29  ...
# 4            1623.0         5664.0                  Web   en  1994-04-01  ...
# ...             ...            ...                  ...  ...         ...  ...
# 69499      100411.0       283642.0         Angel's Tomb   en  2015-07-17  ...
# 69500        2054.0         9446.0            Boomerang  zhs  1997-03-24  ...
# 69501       37957.0        21808.0       Celestine Reef   en  2009-09-04  ...
# 69502       11217.0          893.0         Horned Troll   en  2003-07-28  ...
# 69503      155714.0       315361.0  Exultant Skymarcher   en  2018-01-19  ...
#
#       watermark frame_effects  loyalty card_faces tcgplayer_etched_id  \
# 0           NaN           NaN      NaN        NaN                 NaN
# 1           NaN           NaN      NaN        NaN                 NaN
# 2           NaN           NaN      NaN        NaN                 NaN
# 3           NaN           NaN      NaN        NaN                 NaN
# 4           NaN           NaN      NaN        NaN                 NaN
# ...         ...           ...      ...        ...                 ...
# 69499       NaN           NaN      NaN        NaN                 NaN
# 69500       NaN           NaN      NaN        NaN                 NaN
# 69501       NaN           NaN      NaN        NaN                 NaN
# 69502       NaN           NaN      NaN        NaN                 NaN
# 69503       NaN           NaN      NaN        NaN                 NaN
#
#       color_indicator life_modifier hand_modifier variation_of flavor_name
# 0                 NaN           NaN           NaN          NaN         NaN
# 1                 NaN           NaN           NaN          NaN         NaN
# 2                 NaN           NaN           NaN          NaN         NaN
# 3                 NaN           NaN           NaN          NaN         NaN
# 4                 NaN           NaN           NaN          NaN         NaN
# ...               ...           ...           ...          ...         ...
# 69499             NaN           NaN           NaN          NaN         NaN
# 69500             NaN           NaN           NaN          NaN         NaN
# 69501             NaN           NaN           NaN          NaN         NaN
# 69502             NaN           NaN           NaN          NaN         NaN
# 69503             NaN           NaN           NaN          NaN         NaN
#
# [69504 rows x 64 columns]

# %%
scryfall_dropped_df.rename(columns={'id':'scryfallId'})
# Out:
#       object                            scryfallId  \
# 0       card  0000579f-7b35-4ed3-b44c-db2a538066fe
# 1       card  00006596-1166-4a79-8443-ca9f82e6db4e
# 2       card  0000a54c-a511-4925-92dc-01b937f9afad
# 3       card  0000cd57-91fe-411f-b798-646e965eec37
# 4       card  00012bd8-ed68-4978-a22d-f450c8a6e048
# ...      ...                                   ...
# 69499   card  fffaa737-ce46-4f35-aa8c-bd9bb77ed9f6
# 69500   card  fffc0bfd-8e64-44bf-ae0a-5d2ee54c58df
# 69501   card  fffcbc4e-c6dc-4808-b262-f7c453e74dd8
# 69502   card  fffce2f7-b619-4483-a75e-916343194641
# 69503   card  fffe7b2b-22c3-4e6a-9b1b-c6d7b29b9f86
#
#                                   oracle_id  mtgo_id  mtgo_foil_id  \
# 0      44623693-51d6-49ad-8cd7-140505caf02f  25527.0       25528.0
# 1      8ae3562f-28b7-4462-96ed-be0cf7052ccc  34586.0       34587.0
# 2      dc4e2134-f0c2-49aa-9ea3-ebf83af1445c      NaN           NaN
# 3      9f0d82ae-38bf-45d8-8cda-982b6ead1d72  65170.0       65171.0
# 4      5aa12aff-db3c-4be5-822b-3afdf536b33e      NaN           NaN
# ...                                     ...      ...           ...
# 69499  de3ed52e-7cc2-49ea-96d9-4254aac46168  57710.0       57711.0
# 69500  dc4a4996-108a-4aac-850f-2d9f76403446      NaN           NaN
# 69501  2979597d-c3cc-4585-a9b7-7fa15641b030      NaN           NaN
# 69502  6ecc61ff-719a-405d-b02a-01607729d05c  19591.0       19592.0
# 69503  d7ebd4a7-c542-469f-8a1c-d48b92fa540a  66467.0           NaN
#
#        tcgplayer_id  cardmarket_id                 name lang released_at  ...  \
# 0           14240.0        13850.0          Fury Sliver   en  2006-10-06  ...
# 1           33347.0        21851.0        Kor Outfitter   en  2009-10-02  ...
# 2           98659.0            NaN               Spirit   en  2015-05-22  ...
# 3          145764.0       301766.0        Siren Lookout   en  2017-09-29  ...
# 4            1623.0         5664.0                  Web   en  1994-04-01  ...
# ...             ...            ...                  ...  ...         ...  ...
# 69499      100411.0       283642.0         Angel's Tomb   en  2015-07-17  ...
# 69500        2054.0         9446.0            Boomerang  zhs  1997-03-24  ...
# 69501       37957.0        21808.0       Celestine Reef   en  2009-09-04  ...
# 69502       11217.0          893.0         Horned Troll   en  2003-07-28  ...
# 69503      155714.0       315361.0  Exultant Skymarcher   en  2018-01-19  ...
#
#       watermark frame_effects  loyalty card_faces tcgplayer_etched_id  \
# 0           NaN           NaN      NaN        NaN                 NaN
# 1           NaN           NaN      NaN        NaN                 NaN
# 2           NaN           NaN      NaN        NaN                 NaN
# 3           NaN           NaN      NaN        NaN                 NaN
# 4           NaN           NaN      NaN        NaN                 NaN
# ...         ...           ...      ...        ...                 ...
# 69499       NaN           NaN      NaN        NaN                 NaN
# 69500       NaN           NaN      NaN        NaN                 NaN
# 69501       NaN           NaN      NaN        NaN                 NaN
# 69502       NaN           NaN      NaN        NaN                 NaN
# 69503       NaN           NaN      NaN        NaN                 NaN
#
#       color_indicator life_modifier hand_modifier variation_of flavor_name
# 0                 NaN           NaN           NaN          NaN         NaN
# 1                 NaN           NaN           NaN          NaN         NaN
# 2                 NaN           NaN           NaN          NaN         NaN
# 3                 NaN           NaN           NaN          NaN         NaN
# 4                 NaN           NaN           NaN          NaN         NaN
# ...               ...           ...           ...          ...         ...
# 69499             NaN           NaN           NaN          NaN         NaN
# 69500             NaN           NaN           NaN          NaN         NaN
# 69501             NaN           NaN           NaN          NaN         NaN
# 69502             NaN           NaN           NaN          NaN         NaN
# 69503             NaN           NaN           NaN          NaN         NaN
#
# [69504 rows x 64 columns]

# %%
merged_df = pd.merge(scryfall_dropped_df, mtgjson_dropped_df, how="outer")

# %%
merged_df
# Out:
#         object                                    id  \
# 0         card  0000579f-7b35-4ed3-b44c-db2a538066fe
# 1         card  0000579f-7b35-4ed3-b44c-db2a538066fe
# 2         card  0000579f-7b35-4ed3-b44c-db2a538066fe
# 3         card  a8a64329-09fc-4e0d-b7d1-378635f2801a
# 4         card  a8a64329-09fc-4e0d-b7d1-378635f2801a
# ...        ...                                   ...
# 2871769    NaN                                   NaN
# 2871770    NaN                                   NaN
# 2871771    NaN                                   NaN
# 2871772    NaN                                   NaN
# 2871773    NaN                                   NaN
#
#                                     oracle_id  mtgo_id  mtgo_foil_id  \
# 0        44623693-51d6-49ad-8cd7-140505caf02f  25527.0       25528.0
# 1        44623693-51d6-49ad-8cd7-140505caf02f  25527.0       25528.0
# 2        44623693-51d6-49ad-8cd7-140505caf02f  25527.0       25528.0
# 3        44623693-51d6-49ad-8cd7-140505caf02f      NaN           NaN
# 4        44623693-51d6-49ad-8cd7-140505caf02f      NaN           NaN
# ...                                       ...      ...           ...
# 2871769                                   NaN      NaN           NaN
# 2871770                                   NaN      NaN           NaN
# 2871771                                   NaN      NaN           NaN
# 2871772                                   NaN      NaN           NaN
# 2871773                                   NaN      NaN           NaN
#
#          tcgplayer_id  cardmarket_id  \
# 0             14240.0        13850.0
# 1             14240.0        13850.0
# 2             14240.0        13850.0
# 3            233928.0       545126.0
# 4            233928.0       545126.0
# ...               ...            ...
# 2871769           NaN            NaN
# 2871770           NaN            NaN
# 2871771           NaN            NaN
# 2871772           NaN            NaN
# 2871773           NaN            NaN
#
#                                                       name lang released_at  \
# 0                                              Fury Sliver   en  2006-10-06
# 1                                              Fury Sliver   en  2006-10-06
# 2                                              Fury Sliver   en  2006-10-06
# 3                                              Fury Sliver   en  2021-03-19
# 4                                              Fury Sliver   en  2021-03-19
# ...                                                    ...  ...         ...
# 2871769  Hanweir Garrison // Hanweir, the Writhing Town...  NaN         NaT
# 2871770  Hanweir Battlements // Hanweir, the Writhing T...  NaN         NaT
# 2871771  Hanweir Battlements // Hanweir, the Writhing T...  NaN         NaT
# 2871772                       Graf Rats // Chittering Host  NaN         NaT
# 2871773             Midnight Scavengers // Chittering Host  NaN         NaT
#
#          ... hand_modifier variation_of  flavor_name availability  \
# 0        ...           NaN          NaN          NaN   mtgo,paper
# 1        ...           NaN          NaN          NaN        paper
# 2        ...           NaN          NaN          NaN   mtgo,paper
# 3        ...           NaN          NaN          NaN   mtgo,paper
# 4        ...           NaN          NaN          NaN        paper
# ...      ...           ...          ...          ...          ...
# 2871769  ...           NaN          NaN          NaN   mtgo,paper
# 2871770  ...           NaN          NaN          NaN        paper
# 2871771  ...           NaN          NaN          NaN   mtgo,paper
# 2871772  ...           NaN          NaN          NaN   mtgo,paper
# 2871773  ...           NaN          NaN          NaN   mtgo,paper
#
#         boosterTypes                           mtgjsonV4Id  \
# 0              draft  4f7df1f9-a62f-59ce-a36a-d99dd2f53d9f
# 1              draft  e1c8d8ec-63e7-5e10-8148-96fda95c1782
# 2                NaN  5313e542-ac76-540e-b41d-c81df3a45a1d
# 3              draft  4f7df1f9-a62f-59ce-a36a-d99dd2f53d9f
# 4              draft  e1c8d8ec-63e7-5e10-8148-96fda95c1782
# ...              ...                                   ...
# 2871769        draft  f90b6522-40f5-5f38-8bb9-6620a86e224b
# 2871770          NaN  6679a3dc-3671-53d5-a397-2e29e2c70336
# 2871771        draft  f76a5f8a-c91a-57dc-bd79-a7b641826db2
# 2871772        draft  9e46a872-8637-50c4-b0ff-c0ee5a8bdfa3
# 2871773        draft  0b8bdf8a-bd5c-5f77-9d0c-238d2bf42056
#
#                                               purchaseUrls  \
# 0        {'tcgplayer': 'https://mtgjson.com/links/5c363...
# 1        {'tcgplayer': 'https://mtgjson.com/links/be728...
# 2        {'tcgplayer': 'https://mtgjson.com/links/e9692...
# 3        {'tcgplayer': 'https://mtgjson.com/links/5c363...
# 4        {'tcgplayer': 'https://mtgjson.com/links/be728...
# ...                                                    ...
# 2871769  {'tcgplayer': 'https://mtgjson.com/links/9f0d1...
# 2871770  {'tcgplayer': 'https://mtgjson.com/links/064af...
# 2871771  {'tcgplayer': 'https://mtgjson.com/links/f7128...
# 2871772  {'tcgplayer': 'https://mtgjson.com/links/5412d...
# 2871773  {'tcgplayer': 'https://mtgjson.com/links/38615...
#
#                                    scryfallId setCode  \
# 0        0000579f-7b35-4ed3-b44c-db2a538066fe     TSP
# 1        a8a64329-09fc-4e0d-b7d1-378635f2801a     TSR
# 2        eed1b11e-ca86-4b1b-b989-3a59e5772099     H09
# 3        0000579f-7b35-4ed3-b44c-db2a538066fe     TSP
# 4        a8a64329-09fc-4e0d-b7d1-378635f2801a     TSR
# ...                                       ...     ...
# 2871769  0900e494-962d-48c6-8e78-66a489be4bb2     EMN
# 2871770  a32261f2-164f-4433-bc4c-b5ac591e6a59    PEMN
# 2871771  1d743ad6-6ca2-409a-9773-581cc195dbf2     EMN
# 2871772  3dedaff6-bd69-4fe3-a301-f7ea7c2f2861     EMN
# 2871773  5a57187c-f0ec-40de-b725-786f787b00a2     EMN
#
#                                          uuid
# 0        9f203094-9e28-5fef-847b-5508b798ec53
# 1        f636625b-4d83-5446-a49f-e48f1987b073
# 2        0c8d4641-e3e8-5915-b659-4f416bffaeef
# 3        9f203094-9e28-5fef-847b-5508b798ec53
# 4        f636625b-4d83-5446-a49f-e48f1987b073
# ...                                       ...
# 2871769  68858e2c-9998-566e-a653-52cf1120957a
# 2871770  cd64fa60-1cac-5a26-a37a-9bd33742bbe9
# 2871771  ded0b33b-e9ad-58ee-ba5a-2529756c398a
# 2871772  d8483bbd-7271-5fd3-9892-38473dc69f8b
# 2871773  639f197b-8f7f-5981-9d9d-c652c1a970b6
#
# [2871774 rows x 71 columns]

# %%
merged_dropped_df=merged_df.drop_duplicates(subset=['id'])

# %%
merged_dropped_df
# Out:
#         object                                    id  \
# 0         card  0000579f-7b35-4ed3-b44c-db2a538066fe
# 3         card  a8a64329-09fc-4e0d-b7d1-378635f2801a
# 6         card  eed1b11e-ca86-4b1b-b989-3a59e5772099
# 9         card  00006596-1166-4a79-8443-ca9f82e6db4e
# 10        card  0000a54c-a511-4925-92dc-01b937f9afad
# ...        ...                                   ...
# 2871758   card  ffe93b27-f8ae-4abf-8ade-90f503f132c2
# 2871759   card  ffeb407d-6a42-488a-9869-83da3047e45d
# 2871760   card  ffedba3e-8e4b-430c-8428-170d393918cf
# 2871761   card  fff6ed1f-aaee-4f0e-b9f9-a377e66f9049
# 2871762    NaN                                   NaN
#
#                                     oracle_id  mtgo_id  mtgo_foil_id  \
# 0        44623693-51d6-49ad-8cd7-140505caf02f  25527.0       25528.0
# 3        44623693-51d6-49ad-8cd7-140505caf02f      NaN           NaN
# 6        44623693-51d6-49ad-8cd7-140505caf02f  35350.0       35351.0
# 9        8ae3562f-28b7-4462-96ed-be0cf7052ccc  34586.0       34587.0
# 10       dc4e2134-f0c2-49aa-9ea3-ebf83af1445c      NaN           NaN
# ...                                       ...      ...           ...
# 2871758  6d37ba4b-ff56-4eec-9dc2-2d7f357dc9c9  87287.0           NaN
# 2871759  a57b84e4-951c-4475-bb34-b68815858f87  51751.0       51752.0
# 2871760  a713aff7-149d-4a98-9fc3-c0df37f63929      NaN           NaN
# 2871761  bf84cf9a-6cc2-46d0-8c79-62ce3bd7542b      NaN           NaN
# 2871762                                   NaN      NaN           NaN
#
#          tcgplayer_id  cardmarket_id  \
# 0             14240.0        13850.0
# 3            233928.0       545126.0
# 6             37059.0        22062.0
# 9             33347.0        21851.0
# 10            98659.0            NaN
# ...               ...            ...
# 2871758      229263.0       527575.0
# 2871759       79134.0       266014.0
# 2871760      132364.0       298303.0
# 2871761           NaN            NaN
# 2871762           NaN            NaN
#
#                                                       name lang released_at  \
# 0                                              Fury Sliver   en  2006-10-06
# 3                                              Fury Sliver   en  2021-03-19
# 6                                              Fury Sliver   en  2009-11-20
# 9                                            Kor Outfitter   en  2009-10-02
# 10                                                  Spirit   en  2015-05-22
# ...                                                    ...  ...         ...
# 2871758                                  Youthful Valkyrie   en  2021-02-05
# 2871759                                        Hold at Bay   en  2014-02-07
# 2871760                          My Forces Are Innumerable   en  2017-06-16
# 2871761                     A Little Chat // A Little Chat   en  2022-04-29
# 2871762  Bruna, the Fading Light // Brisela, Voice of N...  NaN         NaT
#
#          ... hand_modifier variation_of  flavor_name      availability  \
# 0        ...           NaN          NaN          NaN        mtgo,paper
# 3        ...           NaN          NaN          NaN        mtgo,paper
# 6        ...           NaN          NaN          NaN        mtgo,paper
# 9        ...           NaN          NaN          NaN        mtgo,paper
# 10       ...           NaN          NaN          NaN               NaN
# ...      ...           ...          ...          ...               ...
# 2871758  ...           NaN          NaN          NaN  arena,mtgo,paper
# 2871759  ...           NaN          NaN          NaN        mtgo,paper
# 2871760  ...           NaN          NaN          NaN             paper
# 2871761  ...           NaN          NaN          NaN               NaN
# 2871762  ...           NaN          NaN          NaN             paper
#
#         boosterTypes                           mtgjsonV4Id  \
# 0              draft  4f7df1f9-a62f-59ce-a36a-d99dd2f53d9f
# 3              draft  4f7df1f9-a62f-59ce-a36a-d99dd2f53d9f
# 6              draft  4f7df1f9-a62f-59ce-a36a-d99dd2f53d9f
# 9              draft  6679505b-9719-5b75-94b3-46f47484a61f
# 10               NaN                                   NaN
# ...              ...                                   ...
# 2871758          NaN  1011065f-64db-5a39-8029-2c82a646f037
# 2871759        draft  8abd2926-f70c-5fd1-b2ae-e2e791892147
# 2871760          NaN  84610af5-76aa-5af2-98ff-12c0a095e82e
# 2871761          NaN                                   NaN
# 2871762          NaN  16c1f28e-e61f-5971-8bd1-351be28f31d2
#
#                                               purchaseUrls  \
# 0        {'tcgplayer': 'https://mtgjson.com/links/5c363...
# 3        {'tcgplayer': 'https://mtgjson.com/links/5c363...
# 6        {'tcgplayer': 'https://mtgjson.com/links/5c363...
# 9        {'tcgplayer': 'https://mtgjson.com/links/754ef...
# 10                                                     NaN
# ...                                                    ...
# 2871758  {'tcgplayer': 'https://mtgjson.com/links/4574a...
# 2871759  {'tcgplayer': 'https://mtgjson.com/links/7a8ee...
# 2871760  {'tcgplayer': 'https://mtgjson.com/links/f67c6...
# 2871761                                                NaN
# 2871762  {'tcgplayer': 'https://mtgjson.com/links/45539...
#
#                                    scryfallId setCode  \
# 0        0000579f-7b35-4ed3-b44c-db2a538066fe     TSP
# 3        0000579f-7b35-4ed3-b44c-db2a538066fe     TSP
# 6        0000579f-7b35-4ed3-b44c-db2a538066fe     TSP
# 9        00006596-1166-4a79-8443-ca9f82e6db4e     ZEN
# 10                                        NaN     NaN
# ...                                       ...     ...
# 2871758  ffe93b27-f8ae-4abf-8ade-90f503f132c2     KHM
# 2871759  ffeb407d-6a42-488a-9869-83da3047e45d     BNG
# 2871760  ffedba3e-8e4b-430c-8428-170d393918cf    OE01
# 2871761                                   NaN     NaN
# 2871762  09c010da-1f05-4ab2-a8e7-f9d7762ea502    PEMN
#
#                                          uuid
# 0        9f203094-9e28-5fef-847b-5508b798ec53
# 3        9f203094-9e28-5fef-847b-5508b798ec53
# 6        9f203094-9e28-5fef-847b-5508b798ec53
# 9        1ede19f5-c7fd-5afe-974d-6d657e428a64
# 10                                        NaN
# ...                                       ...
# 2871758  3b29814d-2076-5ce8-9bee-532ae666436c
# 2871759  cab3cdd9-35ee-5553-ae56-5e1581ab5559
# 2871760  4dbcf063-4a9d-5ba8-a0d7-cd0d6608cfdd
# 2871761                                   NaN
# 2871762  45272fb2-2ad7-5057-ae0a-8af19aca0bca
#
# [69505 rows x 71 columns]

# %%
merged_dropped_df.reset_index()
# Out:
#          index object                                    id  \
# 0            0   card  0000579f-7b35-4ed3-b44c-db2a538066fe
# 1            3   card  a8a64329-09fc-4e0d-b7d1-378635f2801a
# 2            6   card  eed1b11e-ca86-4b1b-b989-3a59e5772099
# 3            9   card  00006596-1166-4a79-8443-ca9f82e6db4e
# 4           10   card  0000a54c-a511-4925-92dc-01b937f9afad
# ...        ...    ...                                   ...
# 69500  2871758   card  ffe93b27-f8ae-4abf-8ade-90f503f132c2
# 69501  2871759   card  ffeb407d-6a42-488a-9869-83da3047e45d
# 69502  2871760   card  ffedba3e-8e4b-430c-8428-170d393918cf
# 69503  2871761   card  fff6ed1f-aaee-4f0e-b9f9-a377e66f9049
# 69504  2871762    NaN                                   NaN
#
#                                   oracle_id  mtgo_id  mtgo_foil_id  \
# 0      44623693-51d6-49ad-8cd7-140505caf02f  25527.0       25528.0
# 1      44623693-51d6-49ad-8cd7-140505caf02f      NaN           NaN
# 2      44623693-51d6-49ad-8cd7-140505caf02f  35350.0       35351.0
# 3      8ae3562f-28b7-4462-96ed-be0cf7052ccc  34586.0       34587.0
# 4      dc4e2134-f0c2-49aa-9ea3-ebf83af1445c      NaN           NaN
# ...                                     ...      ...           ...
# 69500  6d37ba4b-ff56-4eec-9dc2-2d7f357dc9c9  87287.0           NaN
# 69501  a57b84e4-951c-4475-bb34-b68815858f87  51751.0       51752.0
# 69502  a713aff7-149d-4a98-9fc3-c0df37f63929      NaN           NaN
# 69503  bf84cf9a-6cc2-46d0-8c79-62ce3bd7542b      NaN           NaN
# 69504                                   NaN      NaN           NaN
#
#        tcgplayer_id  cardmarket_id  \
# 0           14240.0        13850.0
# 1          233928.0       545126.0
# 2           37059.0        22062.0
# 3           33347.0        21851.0
# 4           98659.0            NaN
# ...             ...            ...
# 69500      229263.0       527575.0
# 69501       79134.0       266014.0
# 69502      132364.0       298303.0
# 69503           NaN            NaN
# 69504           NaN            NaN
#
#                                                     name lang  ...  \
# 0                                            Fury Sliver   en  ...
# 1                                            Fury Sliver   en  ...
# 2                                            Fury Sliver   en  ...
# 3                                          Kor Outfitter   en  ...
# 4                                                 Spirit   en  ...
# ...                                                  ...  ...  ...
# 69500                                  Youthful Valkyrie   en  ...
# 69501                                        Hold at Bay   en  ...
# 69502                          My Forces Are Innumerable   en  ...
# 69503                     A Little Chat // A Little Chat   en  ...
# 69504  Bruna, the Fading Light // Brisela, Voice of N...  NaN  ...
#
#       hand_modifier variation_of flavor_name      availability boosterTypes  \
# 0               NaN          NaN         NaN        mtgo,paper        draft
# 1               NaN          NaN         NaN        mtgo,paper        draft
# 2               NaN          NaN         NaN        mtgo,paper        draft
# 3               NaN          NaN         NaN        mtgo,paper        draft
# 4               NaN          NaN         NaN               NaN          NaN
# ...             ...          ...         ...               ...          ...
# 69500           NaN          NaN         NaN  arena,mtgo,paper          NaN
# 69501           NaN          NaN         NaN        mtgo,paper        draft
# 69502           NaN          NaN         NaN             paper          NaN
# 69503           NaN          NaN         NaN               NaN          NaN
# 69504           NaN          NaN         NaN             paper          NaN
#
#                                 mtgjsonV4Id  \
# 0      4f7df1f9-a62f-59ce-a36a-d99dd2f53d9f
# 1      4f7df1f9-a62f-59ce-a36a-d99dd2f53d9f
# 2      4f7df1f9-a62f-59ce-a36a-d99dd2f53d9f
# 3      6679505b-9719-5b75-94b3-46f47484a61f
# 4                                       NaN
# ...                                     ...
# 69500  1011065f-64db-5a39-8029-2c82a646f037
# 69501  8abd2926-f70c-5fd1-b2ae-e2e791892147
# 69502  84610af5-76aa-5af2-98ff-12c0a095e82e
# 69503                                   NaN
# 69504  16c1f28e-e61f-5971-8bd1-351be28f31d2
#
#                                             purchaseUrls  \
# 0      {'tcgplayer': 'https://mtgjson.com/links/5c363...
# 1      {'tcgplayer': 'https://mtgjson.com/links/5c363...
# 2      {'tcgplayer': 'https://mtgjson.com/links/5c363...
# 3      {'tcgplayer': 'https://mtgjson.com/links/754ef...
# 4                                                    NaN
# ...                                                  ...
# 69500  {'tcgplayer': 'https://mtgjson.com/links/4574a...
# 69501  {'tcgplayer': 'https://mtgjson.com/links/7a8ee...
# 69502  {'tcgplayer': 'https://mtgjson.com/links/f67c6...
# 69503                                                NaN
# 69504  {'tcgplayer': 'https://mtgjson.com/links/45539...
#
#                                  scryfallId setCode  \
# 0      0000579f-7b35-4ed3-b44c-db2a538066fe     TSP
# 1      0000579f-7b35-4ed3-b44c-db2a538066fe     TSP
# 2      0000579f-7b35-4ed3-b44c-db2a538066fe     TSP
# 3      00006596-1166-4a79-8443-ca9f82e6db4e     ZEN
# 4                                       NaN     NaN
# ...                                     ...     ...
# 69500  ffe93b27-f8ae-4abf-8ade-90f503f132c2     KHM
# 69501  ffeb407d-6a42-488a-9869-83da3047e45d     BNG
# 69502  ffedba3e-8e4b-430c-8428-170d393918cf    OE01
# 69503                                   NaN     NaN
# 69504  09c010da-1f05-4ab2-a8e7-f9d7762ea502    PEMN
#
#                                        uuid
# 0      9f203094-9e28-5fef-847b-5508b798ec53
# 1      9f203094-9e28-5fef-847b-5508b798ec53
# 2      9f203094-9e28-5fef-847b-5508b798ec53
# 3      1ede19f5-c7fd-5afe-974d-6d657e428a64
# 4                                       NaN
# ...                                     ...
# 69500  3b29814d-2076-5ce8-9bee-532ae666436c
# 69501  cab3cdd9-35ee-5553-ae56-5e1581ab5559
# 69502  4dbcf063-4a9d-5ba8-a0d7-cd0d6608cfdd
# 69503                                   NaN
# 69504  45272fb2-2ad7-5057-ae0a-8af19aca0bca
#
# [69505 rows x 72 columns]

# %%
all_merged_df =
